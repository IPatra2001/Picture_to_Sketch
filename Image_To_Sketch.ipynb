# %% [markdown]
# <h1 style="background-color:Gray;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 30px 30px;color:White;">
#  Image to Pencil Sketch Using Python✏️
# </h1>

# %% [markdown]
# ### Overview
#
# Introduction:
# The conversion of images to pencil sketches using Python is a fascinating project that leverages image processing techniques to transform digital photographs into artistic sketches. This project is an excellent way to explore the capabilities of libraries like OpenCV, which provides a wide range of functions for image manipulation and transformation.

# %% [markdown]
# Objectives:
#
#  * Understand Image Processing Basics: Learn the fundamental concepts of image processing and how to apply them using Python.
#  * Library Utilization: Use OpenCV for reading, processing, and transforming images.
#  * Pencil Sketch Effect: Implement techniques to convert a colored image into a grayscale image and apply edge detection to   create a pencil sketch effect.
#  * Enhancement and Customization: Fine-tune parameters to improve the sketch quality and allow customization of the sketch effect.

# %% [markdown]
# ###  Loading Libraries

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
# !pip install opencv-python

# %%
# !pip install opencv-contrib-python

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0

# %%
image = mpimg.imread("1606124476103.png")
plt.imshow(image)

# %% [markdown]
# ### Grey Image

# %% [markdown]
# To decrease the complexity of the image and make the handling easier we will be converting the image to a grayscale image with the help of the cvtColor function.

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')

# %% [markdown]
# ### Inverted Grey Image

# %% [markdown]
# Now the next step is to invert the image. Because when an image is inverted it helps in studying the image with more precision and detail.
# The more detailed study is important for the sketch generation as the sketches need to be accurate and good.

# %%
inverted_image = 255 - gray_image
plt.imshow(inverted_image, cmap='Greys_r')

# %% [markdown]
# ### Blurred Image

# %% [markdown]
# In addition to this, we will also be smoothing the image to make sure the sketch we obtain is less edgy and smooth.

# %%
inverted_blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

ax1.set_title('inverted gray')
ax1.imshow(inverted_image, cmap='Greys_r')

ax2.set_title('inverted blurred image')
ax2.imshow(inverted_blurred, cmap='Greys_r')

# %% [markdown]
# ### Pencil Sketch

# %% [markdown]
# Now that the whole image processing is done, we will be passing the previous outputs to the function and pass the right and accurate parameters to make the appropriate changes to the image.

# %%
final = cv2.divide(gray_image, 255 - inverted_blurred, scale=240)
plt.figure(figsize=(15,15))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# ### All images in one frame

# %%
plt.figure(figsize=(60,60))
plt.subplot(1,5,1)
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.subplot(1,5,2)
plt.imshow(gray_image, cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.subplot(1,5,3)
plt.imshow(inverted_image,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.subplot(1,5,4)
plt.imshow(inverted_blurred,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.subplot(1,5,5)
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# ### Conclusion
#
# In conclusion, converting images to pencil sketches using Python is a creative and technically enriching project that demonstrates the power of image processing techniques. By leveraging the capabilities of OpenCV, we can transform ordinary photographs into artistic sketches, providing a unique and visually appealing effect. This project not only enhances our understanding of image processing but also showcases the potential for customization and artistic expression through programming.
